# %% [markdown]
# # Qwen2-7B-Instruct beam search figures

# %%
import matplotlib.pyplot as plt
import numpy as np

# categories
x_axis=['Original Sampling','Beam=1 (Greedy)','Beam=3','Beam=5','Beam=7', 'Beam=9']

# evaluation method on advbench data
refusal_classifier = [92.2, 90.8, 83.4, 77.4, 75.6, 74.0]
harmbench = [62.0, 63.2, 64.2, 61.6, 59.0, 57.4]
gemma4 = [61.4, 64.6, 63.4, 62.2, 59.6, 59.2]

# evaluation method on Jbb data
refusal_classifier_jbb = [91.2, 92.6, 86.2, 82.2, 81.0, 77.6]
harmbench_jbb = [54.0, 58.6, 61.0, 58.4, 56.8, 53.8]
gemma4_jbb = [55.0, 58.6, 59.2, 57.0, 56.4, 52.0]

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 7))
# fig, ax = plt.subplots(figsize=(9,7))

# plot for advbench dataset
ax1.plot(x_axis, refusal_classifier,'o-',label='Refusal Classifier')
ax1.plot(x_axis, harmbench,'o-',label='Harmbench')
ax1.plot(x_axis, gemma4,'o-',label='Gemma-4-26B-A4B-it')

ax1.set_ylabel('Average ASR across 5 seeds (%)')
ax1.set_xlabel('LLM decoding method')
ax1.set_title('Advbench dataset')
# ax1.set_ylim(top=95)
ax1.set_ylim(10, 95)
ax1.legend()

# plot for jbb dataset
ax2.plot(x_axis, refusal_classifier_jbb,'o-',label='Refusal Classifier')
ax2.plot(x_axis, harmbench_jbb,'o-',label='Harmbench')
ax2.plot(x_axis, gemma4_jbb,'o-',label='Gemma-4-26B-A4B-it')

ax2.set_ylabel('Average ASR across 5 seeds (%)')
ax2.set_xlabel('LLM decoding method')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(10, 95)
ax2.legend()

fig.suptitle("Qwen2-7B-Instruct DSN", fontsize=16)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# categories
x_axis=['Original Sampling','Beam=1 (Greedy)','Beam=3','Beam=5','Beam=7', 'Beam=9']

# evaluation method on advbench data
refusal_classifier = [80.6, 83.6, 63.8, 57.0, 55.0, 54.4]
harmbench = [54.4, 58.0, 46.8, 41.8, 41.6, 41.8]
gemma4 = [53.8, 56.0, 45.4, 38.6, 39.2, 39.4]

# evaluation method on Jbb data
refusal_classifier_jbb = [84.8, 85.4, 75.0, 71.4, 67.8, 67.2]
harmbench_jbb = [52.6, 55.8, 50.0, 47.2, 46.0, 45.0]
gemma4_jbb = [49.6, 53.0, 46.4, 43.0, 42.0, 42.2]

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 7))
# fig, ax = plt.subplots(figsize=(9,7))

# plot for advbench dataset
ax1.plot(x_axis, refusal_classifier,'o-',label='Refusal Classifier')
ax1.plot(x_axis, harmbench,'o-',label='Harmbench')
ax1.plot(x_axis, gemma4,'o-',label='Gemma-4-26B-A4B-it')

ax1.set_ylabel('Average ASR across 5 seeds (%)')
ax1.set_xlabel('LLM decoding method')
ax1.set_title('Advbench dataset')
# ax1.set_ylim(top=95)
ax1.set_ylim(10, 95)
ax1.legend()

# plot for jbb dataset
ax2.plot(x_axis, refusal_classifier_jbb,'o-',label='Refusal Classifier')
ax2.plot(x_axis, harmbench_jbb,'o-',label='Harmbench')
ax2.plot(x_axis, gemma4_jbb,'o-',label='Gemma-4-26B-A4B-it')

ax2.set_ylabel('Average ASR across 5 seeds (%)')
ax2.set_xlabel('LLM decoding method')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(10, 95)
ax2.legend()

fig.suptitle("Qwen2-7B-Instruct GCG", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Qwen2-7B-Instruct keyword list variations

# %% [markdown]
# #

# %%
# advbench
data_all_advbench = {
  'Halved': {
      'Refusal Classifier': [95, 45, 93, 90, 91],
      'Harmbench': [59, 43, 66, 56, 57],
      'Gemma-4-26B-A4B-it': [64, 46, 60, 59, 59]},
  'Curated': {
      'Refusal Classifier': [85, 65, 77, 93, 95],
      'Harmbench': [48, 17, 54, 67, 58],
      'Gemma-4-26B-A4B-it': [49, 15, 49, 66, 57]},
  'Original': {
      'Refusal Classifier': [92, 94, 88, 93, 94],
      'Harmbench': [65, 70, 55, 64, 56],
      'Gemma-4-26B-A4B-it': [58, 70, 56, 64, 59]},
  'Doubled': {
      'Refusal Classifier': [85, 85, 94, 88, 88],
      'Harmbench': [46, 55, 75, 58, 57],
      'Gemma-4-26B-A4B-it': [46, 49, 72, 55, 56]},
  'Tripled': {
      'Refusal Classifier': [78, 70, 77, 87, 91],
      'Harmbench': [45, 17, 54, 64, 56],
      'Gemma-4-26B-A4B-it': [50, 21, 49, 59, 52]}}

list_types = list(data_all_advbench.keys())

# get all seed data
halved_rm = data_all_advbench["Halved"]["Refusal Classifier"]
halved_hm = data_all_advbench["Halved"]["Harmbench"]
halved_gemma = data_all_advbench["Halved"]["Gemma-4-26B-A4B-it"]

curated_rm = data_all_advbench["Curated"]["Refusal Classifier"]
curated_hm = data_all_advbench["Curated"]["Harmbench"]
curated_gemma = data_all_advbench["Curated"]["Gemma-4-26B-A4B-it"]

original_rm = data_all_advbench["Original"]["Refusal Classifier"]
original_hm = data_all_advbench["Original"]["Harmbench"]
original_gemma = data_all_advbench["Original"]["Gemma-4-26B-A4B-it"]

doubled_rm = data_all_advbench["Doubled"]["Refusal Classifier"]
doubled_hm = data_all_advbench["Doubled"]["Harmbench"]
doubled_gemma = data_all_advbench["Doubled"]["Gemma-4-26B-A4B-it"]

tripled_rm = data_all_advbench["Tripled"]["Refusal Classifier"]
tripled_hm = data_all_advbench["Tripled"]["Harmbench"]
tripled_gemma = data_all_advbench["Tripled"]["Gemma-4-26B-A4B-it"]

# refusal means
refusal_means = [np.mean(halved_rm), np.mean(curated_rm), np.mean(original_rm), np.mean(doubled_rm), np.mean(tripled_rm)]
# harmbench means
harmbench_means = [np.mean(halved_hm), np.mean(curated_hm), np.mean(original_hm), np.mean(doubled_hm), np.mean(tripled_hm)]
# gemma4 means
gemma_means = [np.mean(halved_gemma), np.mean(curated_gemma), np.mean(original_gemma), np.mean(doubled_gemma), np.mean(tripled_gemma)]

# jbb dataset
data_all_jbb = {
  'Halved': {
      'Refusal Classifier': [90, 54, 90, 89, 89],
      'Harmbench': [59, 30, 61, 63, 52],
      'Gemma-4-26B-A4B-it': [59, 37, 57, 58, 55]},
  'Curated': {
      'Refusal Classifier': [93, 68, 85, 94, 95],
      'Harmbench': [46, 23, 50, 55, 56],
      'Gemma-4-26B-A4B-it': [49, 20, 46, 55, 54]},
  'Original': {
      'Refusal Classifier': [95, 91, 86, 91, 93],
      'Harmbench': [57, 58, 54, 52, 49],
      'Gemma-4-26B-A4B-it': [57, 60, 51, 52, 55]},
  'Doubled': {
      'Refusal Classifier': [74, 90, 94, 91, 88],
      'Harmbench': [48, 52, 70, 48, 47],
      'Gemma-4-26B-A4B-it': [58, 54, 65, 42, 46]},
  'Tripled': {
      'Refusal Classifier': [83, 83, 85, 90, 92],
      'Harmbench': [57, 30, 50, 61, 44],
      'Gemma-4-26B-A4B-it': [67, 36, 46, 58, 42]}}

list_types_jbb = list(data_all_jbb.keys())

# get all seed data
halved_rm_jbb = data_all_jbb["Halved"]["Refusal Classifier"]
halved_hm_jbb = data_all_jbb["Halved"]["Harmbench"]
halved_gemma_jbb = data_all_jbb["Halved"]["Gemma-4-26B-A4B-it"]

curated_rm_jbb = data_all_jbb["Curated"]["Refusal Classifier"]
curated_hm_jbb = data_all_jbb["Curated"]["Harmbench"]
curated_gemma_jbb = data_all_jbb["Curated"]["Gemma-4-26B-A4B-it"]

original_rm_jbb = data_all_jbb["Original"]["Refusal Classifier"]
original_hm_jbb = data_all_jbb["Original"]["Harmbench"]
original_gemma_jbb = data_all_jbb["Original"]["Gemma-4-26B-A4B-it"]

doubled_rm_jbb = data_all_jbb["Doubled"]["Refusal Classifier"]
doubled_hm_jbb = data_all_jbb["Doubled"]["Harmbench"]
doubled_gemma_jbb = data_all_jbb["Doubled"]["Gemma-4-26B-A4B-it"]

tripled_rm_jbb = data_all_jbb["Tripled"]["Refusal Classifier"]
tripled_hm_jbb = data_all_jbb["Tripled"]["Harmbench"]
tripled_gemma_jbb = data_all_jbb["Tripled"]["Gemma-4-26B-A4B-it"]

# refusal means
refusal_means_jbb = [np.mean(halved_rm_jbb), np.mean(curated_rm_jbb), np.mean(original_rm_jbb), np.mean(doubled_rm_jbb), np.mean(tripled_rm_jbb)]
# harmbench means
harmbench_means_jbb = [np.mean(halved_hm_jbb), np.mean(curated_hm_jbb), np.mean(original_hm_jbb), np.mean(doubled_hm_jbb), np.mean(tripled_hm_jbb)]
# gemma4 means
gemma_means_jbb = [np.mean(halved_gemma_jbb), np.mean(curated_gemma_jbb), np.mean(original_gemma_jbb), np.mean(doubled_gemma_jbb), np.mean(tripled_gemma_jbb)]

# fig, ax = plt.subplots(figsize=(11,7))
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(22, 6))

# Advbench
# plot the Refusal matching points
for i, yvals in enumerate([halved_rm, curated_rm, original_rm, doubled_rm, tripled_rm]):
  x = [i + 0.9] * len(yvals)
  ax1.plot(x, yvals, '-o', c='lightblue', zorder=1, markersize=5)
# plot mean refusal classifier
ax1.scatter([0.9, 1.9, 2.9, 3.9, 4.9], refusal_means, marker='D', label='Refusal Classifier', zorder=10, s=70)

# plot harmbench points
for i, yvals in enumerate([halved_hm, curated_hm, original_hm, doubled_hm, tripled_hm]):
  x = [i + 1.05] * len(yvals)
  ax1.plot(x, yvals, '-o', c='bisque', zorder=1, markersize=5)
# plot mean harmbench
ax1.scatter([1.05, 2.05, 3.05, 4.05, 5.05], harmbench_means, marker='D', label='Harmbench', zorder=10, s=70)

# plot the gemma4 points
for i, yvals in enumerate([halved_gemma, curated_gemma, original_gemma, doubled_gemma, tripled_gemma]):
  x = [i + 1.2] * len(yvals)
  ax1.plot(x, yvals, '-o', c='palegreen', zorder=1, markersize=5)
# plot mean gemma4
ax1.scatter([1.2, 2.2, 3.2, 4.2, 5.2], gemma_means, marker='D', label='Gemma-4-26B-A4B-it', zorder=10, s=70)

ax1.set_xticks([1.05, 2.05, 3.05, 4.05, 5.05])
ax1.set_xticklabels(list_types)
ax1.set_ylabel('ASR (%)')
ax1.set_xlabel('List type')
ax1.set_title('Advbench dataset')
ax1.set_ylim(0, 100)
ax1.legend()

# JBB
# plot the Refusal matching points
for i, yvals in enumerate([halved_rm_jbb, curated_rm_jbb, original_rm_jbb, doubled_rm_jbb, tripled_rm_jbb]):
  x = [i + 0.9] * len(yvals)
  ax2.plot(x, yvals, '-o', c='lightblue', zorder=1, markersize=5)
# plot mean refusal classifier
ax2.scatter([0.9, 1.9, 2.9, 3.9, 4.9], refusal_means_jbb, marker='D', label='Refusal Classifier', zorder=10, s=70)

# plot harmbench points
for i, yvals in enumerate([halved_hm_jbb, curated_hm_jbb, original_hm_jbb, doubled_hm_jbb, tripled_hm_jbb]):
  x = [i + 1.05] * len(yvals)
  ax2.plot(x, yvals, '-o', c='bisque', zorder=1, markersize=5)
# plot mean harmbench
ax2.scatter([1.05, 2.05, 3.05, 4.05, 5.05], harmbench_means_jbb, marker='D', label='Harmbench', zorder=10, s=70)

# plot the gemma4 points
for i, yvals in enumerate([halved_gemma_jbb, curated_gemma_jbb, original_gemma_jbb, doubled_gemma_jbb, tripled_gemma_jbb]):
  x = [i + 1.2] * len(yvals)
  ax2.plot(x, yvals, '-o', c='palegreen', zorder=1, markersize=5)
# plot mean gemma4
ax2.scatter([1.2, 2.2, 3.2, 4.2, 5.2], gemma_means_jbb, marker='D', label='Gemma-4-26B-A4B-it', zorder=10, s=70)

ax2.set_xticks([1.05, 2.05, 3.05, 4.05, 5.05])
ax2.set_xticklabels(list_types)
ax2.set_ylabel('ASR (%)')
ax2.set_xlabel('List type')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(0, 100)
ax2.legend()

fig.suptitle("Qwen2-7B-Instruct", fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Llama-3.1-8B-Instruct beam search figures

# %%
import matplotlib.pyplot as plt
import numpy as np

# categories
x_axis=['Original Sampling','Beam=1 (Greedy)','Beam=3','Beam=5','Beam=7', 'Beam=9']

# evaluation method on advbench data
refusal_classifier = [47.4, 46.4, 37.2, 32.4, 30.0, 27.4]
harmbench = [37.2, 37.0, 30.6, 27.6, 25.0, 22.4]
gemma4 = [34.0 , 32.6, 27.2, 24.4, 21.2, 19.8]

# evaluation method on Jbb data
refusal_classifier_jbb = [55.8, 51.8, 45.2, 39.6, 38.4, 36.8]
harmbench_jbb = [44.6, 42.6, 38.0, 32.4, 31.2, 30.2]
gemma4_jbb = [39.8, 39.4, 34.8, 29.4, 29.4, 27.4]

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 7))
# fig, ax = plt.subplots(figsize=(9,7))

# plot for advbench dataset
ax1.plot(x_axis, refusal_classifier,'o-',label='Refusal Classifier')
ax1.plot(x_axis, harmbench,'o-',label='Harmbench')
ax1.plot(x_axis, gemma4,'o-',label='Gemma-4-26B-A4B-it')

ax1.set_ylabel('Average ASR across 5 seeds (%)')
ax1.set_xlabel('LLM decoding method')
ax1.set_title('Advbench dataset')
ax1.set_ylim(10, 95)
ax1.legend()

# plot for jbb dataset
ax2.plot(x_axis, refusal_classifier_jbb,'o-',label='Refusal Classifier')
ax2.plot(x_axis, harmbench_jbb,'o-',label='Harmbench')
ax2.plot(x_axis, gemma4_jbb,'o-',label='Gemma-4-26B-A4B-it')

ax2.set_ylabel('Average ASR across 5 seeds (%)')
ax2.set_xlabel('LLM decoding method')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(10, 95)
ax2.legend()

fig.suptitle("Llama-3.1-8B-Instruct DSN", fontsize=16)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# categories
x_axis=['Original Sampling','Beam=1 (Greedy)','Beam=3','Beam=5','Beam=7', 'Beam=9']

# evaluation method on advbench data
refusal_classifier = [40.2, 38.6, 30.8, 27.8, 25.2, 23.2]
harmbench = [34.0, 32.0, 25.8, 22.6, 18.0, 16.8]
gemma4 = [24.4 , 22.0, 20.0, 17.2, 14.0, 12.0]

# evaluation method on Jbb data
refusal_classifier_jbb = [52.8, 52.6, 42.8, 38.6, 34.8, 33.2]
harmbench_jbb = [46.0, 46.0, 38.0, 32.8, 29.2, 27.4]
gemma4_jbb = [40.6, 39.2, 34.8, 29.0, 27.0, 24.8]

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 7))
# fig, ax = plt.subplots(figsize=(9,7))

# plot for advbench dataset
ax1.plot(x_axis, refusal_classifier,'o-',label='Refusal Classifier')
ax1.plot(x_axis, harmbench,'o-',label='Harmbench')
ax1.plot(x_axis, gemma4,'o-',label='Gemma-4-26B-A4B-it')

ax1.set_ylabel('Average ASR across 5 seeds (%)')
ax1.set_xlabel('LLM decoding method')
ax1.set_title('Advbench dataset')
ax1.set_ylim(10, 95)
ax1.legend()

# plot for jbb dataset
ax2.plot(x_axis, refusal_classifier_jbb,'o-',label='Refusal Classifier')
ax2.plot(x_axis, harmbench_jbb,'o-',label='Harmbench')
ax2.plot(x_axis, gemma4_jbb,'o-',label='Gemma-4-26B-A4B-it')

ax2.set_ylabel('Average ASR across 5 seeds (%)')
ax2.set_xlabel('LLM decoding method')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(10, 95)
ax2.legend()

fig.suptitle("Llama-3.1-8B-Instruct GCG", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Llama-3.1-8B-Instruct keyword list variations

# %%
# advbench
data_all_advbench = {
  'Halved': {
      'Refusal Classifier': [10, 72, 62, 33, 70],
      'Harmbench': [2, 49, 48, 11, 59],
      'Gemma-4-26B-A4B-it': [2, 39, 52, 9, 39]},
  'Curated': {
      'Refusal Classifier': [51, 49, 38, 45, 64],
      'Harmbench': [43, 42, 26, 37, 59],
      'Gemma-4-26B-A4B-it': [33, 32, 21, 33, 44]},
  'Original': {
      'Refusal Classifier': [11, 62, 60, 45, 59],
      'Harmbench': [7, 40, 53, 36, 50],
      'Gemma-4-26B-A4B-it': [7, 46, 41, 29, 47]},
  'Doubled': {
      'Refusal Classifier': [24, 4, 57, 37, 68],
      'Harmbench': [19, 2, 45, 25, 59],
      'Gemma-4-26B-A4B-it': [16, 3, 39, 25, 40]},
  'Tripled': {
      'Refusal Classifier': [15, 41, 57, 14, 64],
      'Harmbench': [8, 31, 45, 8, 56],
      'Gemma-4-26B-A4B-it': [8, 26, 39, 8, 45]}}

list_types = list(data_all_advbench.keys())

# get all seed data
halved_rm = data_all_advbench["Halved"]["Refusal Classifier"]
halved_hm = data_all_advbench["Halved"]["Harmbench"]
halved_gemma = data_all_advbench["Halved"]["Gemma-4-26B-A4B-it"]

curated_rm = data_all_advbench["Curated"]["Refusal Classifier"]
curated_hm = data_all_advbench["Curated"]["Harmbench"]
curated_gemma = data_all_advbench["Curated"]["Gemma-4-26B-A4B-it"]

original_rm = data_all_advbench["Original"]["Refusal Classifier"]
original_hm = data_all_advbench["Original"]["Harmbench"]
original_gemma = data_all_advbench["Original"]["Gemma-4-26B-A4B-it"]

doubled_rm = data_all_advbench["Doubled"]["Refusal Classifier"]
doubled_hm = data_all_advbench["Doubled"]["Harmbench"]
doubled_gemma = data_all_advbench["Doubled"]["Gemma-4-26B-A4B-it"]

tripled_rm = data_all_advbench["Tripled"]["Refusal Classifier"]
tripled_hm = data_all_advbench["Tripled"]["Harmbench"]
tripled_gemma = data_all_advbench["Tripled"]["Gemma-4-26B-A4B-it"]

# refusal means
refusal_means = [np.mean(halved_rm), np.mean(curated_rm), np.mean(original_rm), np.mean(doubled_rm), np.mean(tripled_rm)]
# harmbench means
harmbench_means = [np.mean(halved_hm), np.mean(curated_hm), np.mean(original_hm), np.mean(doubled_hm), np.mean(tripled_hm)]
# gemma4 means
gemma_means = [np.mean(halved_gemma), np.mean(curated_gemma), np.mean(original_gemma), np.mean(doubled_gemma), np.mean(tripled_gemma)]

# jbb dataset
data_all_jbb = {
  'Halved': {
      'Refusal Classifier': [16, 61, 74, 25, 74],
      'Harmbench': [5, 38, 63, 14, 59],
      'Gemma-4-26B-A4B-it': [4, 33, 65, 10, 51]},
  'Curated': {
      'Refusal Classifier': [48, 50, 53, 58, 65],
      'Harmbench': [42, 44, 39, 49, 60],
      'Gemma-4-26B-A4B-it': [38, 37, 40, 47, 51]},
  'Original': {
      'Refusal Classifier': [12, 69, 74, 57, 67],
      'Harmbench': [10, 44, 60, 51, 58],
      'Gemma-4-26B-A4B-it': [6, 41, 54, 43, 55]},
  'Doubled': {
      'Refusal Classifier': [38, 4, 76, 44, 73],
      'Harmbench': [24, 3, 62, 26, 63],
      'Gemma-4-26B-A4B-it': [21, 3, 55, 28, 48]},
  'Tripled': {
      'Refusal Classifier': [28, 41, 76, 27, 70],
      'Harmbench': [18, 40, 62, 15, 63],
      'Gemma-4-26B-A4B-it': [18, 34, 55, 11, 59]}}

list_types_jbb = list(data_all_jbb.keys())

# get all seed data
halved_rm_jbb = data_all_jbb["Halved"]["Refusal Classifier"]
halved_hm_jbb = data_all_jbb["Halved"]["Harmbench"]
halved_gemma_jbb = data_all_jbb["Halved"]["Gemma-4-26B-A4B-it"]

curated_rm_jbb = data_all_jbb["Curated"]["Refusal Classifier"]
curated_hm_jbb = data_all_jbb["Curated"]["Harmbench"]
curated_gemma_jbb = data_all_jbb["Curated"]["Gemma-4-26B-A4B-it"]

original_rm_jbb = data_all_jbb["Original"]["Refusal Classifier"]
original_hm_jbb = data_all_jbb["Original"]["Harmbench"]
original_gemma_jbb = data_all_jbb["Original"]["Gemma-4-26B-A4B-it"]

doubled_rm_jbb = data_all_jbb["Doubled"]["Refusal Classifier"]
doubled_hm_jbb = data_all_jbb["Doubled"]["Harmbench"]
doubled_gemma_jbb = data_all_jbb["Doubled"]["Gemma-4-26B-A4B-it"]

tripled_rm_jbb = data_all_jbb["Tripled"]["Refusal Classifier"]
tripled_hm_jbb = data_all_jbb["Tripled"]["Harmbench"]
tripled_gemma_jbb = data_all_jbb["Tripled"]["Gemma-4-26B-A4B-it"]

# refusal means
refusal_means_jbb = [np.mean(halved_rm_jbb), np.mean(curated_rm_jbb), np.mean(original_rm_jbb), np.mean(doubled_rm_jbb), np.mean(tripled_rm_jbb)]
# harmbench means
harmbench_means_jbb = [np.mean(halved_hm_jbb), np.mean(curated_hm_jbb), np.mean(original_hm_jbb), np.mean(doubled_hm_jbb), np.mean(tripled_hm_jbb)]
# gemma4 means
gemma_means_jbb = [np.mean(halved_gemma_jbb), np.mean(curated_gemma_jbb), np.mean(original_gemma_jbb), np.mean(doubled_gemma_jbb), np.mean(tripled_gemma_jbb)]

# fig, ax = plt.subplots(figsize=(11,7))
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(22, 6))

# Advbench
# plot the Refusal matching points
for i, yvals in enumerate([halved_rm, curated_rm, original_rm, doubled_rm, tripled_rm]):
  x = [i + 0.9] * len(yvals)
  ax1.plot(x, yvals, '-o', c='lightblue', zorder=1, markersize=5)
# plot mean refusal classifier
ax1.scatter([0.9, 1.9, 2.9, 3.9, 4.9], refusal_means, marker='D', label='Refusal Classifier', zorder=10, s=70)

# plot harmbench points
for i, yvals in enumerate([halved_hm, curated_hm, original_hm, doubled_hm, tripled_hm]):
  x = [i + 1.05] * len(yvals)
  ax1.plot(x, yvals, '-o', c='bisque', zorder=1, markersize=5)
# plot mean harmbench
ax1.scatter([1.05, 2.05, 3.05, 4.05, 5.05], harmbench_means, marker='D', label='Harmbench', zorder=10, s=70)

# plot the gemma4 points
for i, yvals in enumerate([halved_gemma, curated_gemma, original_gemma, doubled_gemma, tripled_gemma]):
  x = [i + 1.2] * len(yvals)
  ax1.plot(x, yvals, '-o', c='palegreen', zorder=1, markersize=5)
# plot mean gemma4
ax1.scatter([1.2, 2.2, 3.2, 4.2, 5.2], gemma_means, marker='D', label='Gemma-4-26B-A4B-it', zorder=10, s=70)

ax1.set_xticks([1.05, 2.05, 3.05, 4.05, 5.05])
ax1.set_xticklabels(list_types)
ax1.set_ylabel('ASR (%)')
ax1.set_xlabel('List type')
ax1.set_title('Advbench dataset')
ax1.set_ylim(0, 100)
ax1.legend()

# JBB
# plot the Refusal matching points
for i, yvals in enumerate([halved_rm_jbb, curated_rm_jbb, original_rm_jbb, doubled_rm_jbb, tripled_rm_jbb]):
  x = [i + 0.9] * len(yvals)
  ax2.plot(x, yvals, '-o', c='lightblue', zorder=1, markersize=5)
# plot mean refusal classifier
ax2.scatter([0.9, 1.9, 2.9, 3.9, 4.9], refusal_means_jbb, marker='D', label='Refusal Classifier', zorder=10, s=70)

# plot harmbench points
for i, yvals in enumerate([halved_hm_jbb, curated_hm_jbb, original_hm_jbb, doubled_hm_jbb, tripled_hm_jbb]):
  x = [i + 1.05] * len(yvals)
  ax2.plot(x, yvals, '-o', c='bisque', zorder=1, markersize=5)
# plot mean harmbench
ax2.scatter([1.05, 2.05, 3.05, 4.05, 5.05], harmbench_means_jbb, marker='D', label='Harmbench', zorder=10, s=70)

# plot the gemma4 points
for i, yvals in enumerate([halved_gemma_jbb, curated_gemma_jbb, original_gemma_jbb, doubled_gemma_jbb, tripled_gemma_jbb]):
  x = [i + 1.2] * len(yvals)
  ax2.plot(x, yvals, '-o', c='palegreen', zorder=1, markersize=5)
# plot mean gemma4
ax2.scatter([1.2, 2.2, 3.2, 4.2, 5.2], gemma_means_jbb, marker='D', label='Gemma-4-26B-A4B-it', zorder=10, s=70)

ax2.set_xticks([1.05, 2.05, 3.05, 4.05, 5.05])
ax2.set_xticklabels(list_types)
ax2.set_ylabel('ASR (%)')
ax2.set_xlabel('List type')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(0, 100)
ax2.legend()

fig.suptitle("Llama-3.1-8B-Instruct", fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Optimization framework modification figures

# %%
import matplotlib.pyplot as plt
import numpy as np

# categories
x_axis=['None (Original)','Top-k','Max','Variance filtering','Entropy filtering']

# evaluation method on advbench data
refusal_classifier = [41, 13, 57, 36, 36]
harmbench = [31, 8, 8, 23, 23]
gemma4 = [26, 5, 7, 23, 23]

# evaluation method on Jbb data
refusal_classifier_jbb = [41, 18, 46, 29, 29]
harmbench_jbb = [40, 14, 9, 18, 18]
gemma4_jbb = [34, 11, 10, 14, 14]

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 7))
# fig, ax = plt.subplots(figsize=(9,7))

# plot for advbench dataset
ax1.plot(x_axis, refusal_classifier,'o-',label='Refusal Classifier')
ax1.plot(x_axis, harmbench,'o-',label='Harmbench')
ax1.plot(x_axis, gemma4,'o-',label='Gemma-4-26B-A4B-it')

ax1.set_ylabel('ASR for seed 42 (%)')
ax1.set_xlabel('Refusal loss modification')
ax1.set_title('Advbench dataset')
ax1.set_ylim(0, 100)
ax1.legend()

# plot for jbb dataset
ax2.plot(x_axis, refusal_classifier_jbb,'o-',label='Refusal Classifier')
ax2.plot(x_axis, harmbench_jbb,'o-',label='Harmbench')
ax2.plot(x_axis, gemma4_jbb,'o-',label='Gemma-4-26B-A4B-it')

ax2.set_ylabel('ASR for seed 42 (%)')
ax2.set_xlabel('Refusal loss modification')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(0, 100)
ax2.legend()

fig.suptitle("Llama-3.1-8B-Instruct Tripled List", fontsize=16)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# categories
x_axis=['None (Original)', 'Top-k','Max','Variance filtering','Entropy filtering']

# evaluation method on advbench data
refusal_classifier = [62, 46, 54, 72, 72]
harmbench = [40, 40, 28, 53, 53]
gemma4 = [46, 32, 29, 36, 36]

# evaluation method on Jbb data
refusal_classifier_jbb = [69, 44, 58, 68, 68]
harmbench_jbb = [44, 32, 33, 50, 50]
gemma4_jbb = [41, 28, 40, 45, 45]

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 7))
# fig, ax = plt.subplots(figsize=(9,7))

# plot for advbench dataset
ax1.plot(x_axis, refusal_classifier,'o-',label='Refusal Classifier')
ax1.plot(x_axis, harmbench,'o-',label='Harmbench')
ax1.plot(x_axis, gemma4,'o-',label='Gemma-4-26B-A4B-it')

ax1.set_ylabel('ASR for seed 42 (%)')
ax1.set_xlabel('Refusal loss modification')
ax1.set_title('Advbench dataset')
ax1.set_ylim(0, 100)
ax1.legend()

# plot for jbb dataset
ax2.plot(x_axis, refusal_classifier_jbb,'o-',label='Refusal Classifier')
ax2.plot(x_axis, harmbench_jbb,'o-',label='Harmbench')
ax2.plot(x_axis, gemma4_jbb,'o-',label='Gemma-4-26B-A4B-it')

ax2.set_ylabel('ASR for seed 42 (%)')
ax2.set_xlabel('Refusal loss modification')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(0, 100)
ax2.legend()

fig.suptitle("Llama-3.1-8B-Instruct Original List", fontsize=16)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# categories
x_axis=['None (Original)','Top-k','Max','Variance filtering','Entropy filtering']

# evaluation method on advbench data
refusal_classifier = [70, 82, 89, 87, 87]
harmbench = [17, 32, 35, 40, 40]
gemma4 = [21, 26, 35, 36, 36]

# evaluation method on Jbb data
refusal_classifier_jbb = [83, 70, 90, 86, 86]
harmbench_jbb = [30, 31, 32, 41, 41]
gemma4_jbb = [36, 29, 29, 39, 39]

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 7))
# fig, ax = plt.subplots(figsize=(9,7))

# plot for advbench dataset
ax1.plot(x_axis, refusal_classifier,'o-',label='Refusal Classifier')
ax1.plot(x_axis, harmbench,'o-',label='Harmbench')
ax1.plot(x_axis, gemma4,'o-',label='Gemma-4-26B-A4B-it')

ax1.set_ylabel('ASR for seed 42 (%)')
ax1.set_xlabel('Refusal loss modification')
ax1.set_title('Advbench dataset')
ax1.set_ylim(0, 100)
ax1.legend(loc='lower left')

# plot for jbb dataset
ax2.plot(x_axis, refusal_classifier_jbb,'o-',label='Refusal Classifier')
ax2.plot(x_axis, harmbench_jbb,'o-',label='Harmbench')
ax2.plot(x_axis, gemma4_jbb,'o-',label='Gemma-4-26B-A4B-it')

ax2.set_ylabel('ASR for seed 42 (%)')
ax2.set_xlabel('Refusal loss modification')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(0, 100)
ax2.legend(loc='lower left')

fig.suptitle("Qwen2-7B-Instruct Tripled List", fontsize=16)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# categories
x_axis=['None (Original)','Top-k','Max','Variance filtering','Entropy filtering']

# evaluation method on advbench data
refusal_classifier = [94, 94, 95, 95, 95]
harmbench = [70, 53, 61, 57, 57]
gemma4 = [70, 51, 57, 60, 60]

# evaluation method on Jbb data
refusal_classifier_jbb = [91, 91, 96, 90, 90]
harmbench_jbb = [58, 51, 56, 56, 56]
gemma4_jbb = [60, 46, 49, 50, 50]

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 7))
# fig, ax = plt.subplots(figsize=(9,7))

# plot for advbench dataset
ax1.plot(x_axis, refusal_classifier,'o-',label='Refusal Classifier')
ax1.plot(x_axis, harmbench,'o-',label='Harmbench')
ax1.plot(x_axis, gemma4,'o-',label='Gemma-4-26B-A4B-it')

ax1.set_ylabel('ASR for seed 42 (%)')
ax1.set_xlabel('Refusal loss modification')
ax1.set_title('Advbench dataset')
ax1.set_ylim(0, 100)
ax1.legend()

# plot for jbb dataset
ax2.plot(x_axis, refusal_classifier_jbb,'o-',label='Refusal Classifier')
ax2.plot(x_axis, harmbench_jbb,'o-',label='Harmbench')
ax2.plot(x_axis, gemma4_jbb,'o-',label='Gemma-4-26B-A4B-it')

ax2.set_ylabel('ASR for seed 42 (%)')
ax2.set_xlabel('Refusal loss modification')
ax2.set_title('JailbreakBench dataset')
ax2.set_ylim(0, 100)
ax2.legend()

fig.suptitle("Qwen2-7B-Instruct Original List", fontsize=16)
plt.tight_layout()
plt.show()
